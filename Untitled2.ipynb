# %%
student_name=input("Please input your name")
student_score=int(input("Please what is your exams score"))
if(student_score>100):
                  print("Invalid input")
elif(student_score<0):
                  print("Invalid input")
else:
                  if(student_score>=80):
                      print("hello")
# Out:
# Please input your name Samuel
# Please what is your exams score 105
# Invalid input
